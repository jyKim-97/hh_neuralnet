# %%
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload

# %%
import utils

reload(utils)
# Out:
# <module 'utils' from '/home/jungyoung/Project/hh_neuralnet/figures/utils.py'>

# %%
utils.backup_fig()
# Out:
# Copy files to ./prev/250421
# ['repr_figures.ipynb']

# %%
utils.set_figure()

# %%
import date
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import date
#
# ModuleNotFoundError: No module named 'date'

# %%
import datetime as dt

# %%
x = dt.datetime.now()

# %%
x.strftime("%y%m%d")
# Out:
# '250421'

# %%
import os
os.listdir("./prev")
# Out:
# []

# %%
fnames = ["250514", "231010", "test"]

# %%
import shutil

# %%
os.copy

# %%
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 shutil.copyfile("./prev", "prev_test")
#
# File ~/anaconda3/lib/python3.11/shutil.py:256, in copyfile(src, dst, follow_symlinks)
#     254     os.symlink(os.readlink(src), dst)
#     255 else:
# --> 256     with open(src, 'rb') as fsrc:
#     257         try:
#     258             with open(dst, 'wb') as fdst:
#     259                 # macOS
#
# IsADirectoryError: [Errno 21] Is a directory: './prev'

# %%
os.listdir("./prev")
# Out:
# []

# %%
x.strftime("%y%m%d")
           # %A %d. %B %Y")
# Out:
# '250421'

# %%
fig = plt.figure(figsize=(6, 1))

plt.plot(data["db
            etails"][1]["ts"], data["details"][0]["vlfp"], color='k')
plt.xlim([1, 2])
# Out:
# (1.0, 2.0)

# %%
font_files = fm.findSystemFonts(fontpaths="./font")
for font_file in font_files:
    fm.fontManager.addfont(font_file)

# %%
plt.rcParams["font.family"] = "Arial"
plt.rcParams['mathtext.fontset'] = 'dejavusans'
# plt.rcParams['mathtext.fontset'] = 'cm'

# Tick property
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams["xtick.minor.visible"] = False
plt.rcParams["ytick.minor.visible"] = False
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['xtick.major.size'] = 5
plt.rcParams['ytick.major.size'] = 5

plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.bottom'] = True
plt.rcParams['axes.spines.left'] = True

plt.rcParams["xtick.labelsize"] = 11
plt.rcParams["ytick.labelsize"] = 11

# Line setting
plt.rcParams["lines.linewidth"] = 1.2

# %%
import pickle as pkl

with open("../two_pop_mpi/postdata/activity_sample.pkl", "rb") as fp:
    data = pkl.load(fp)

# %%
fig = plt.figure(figsize=(6, 1))

plt.plot(data["details"][1]["ts"], data["details"][0]["vlfp"], color='k')
plt.xlim([1, 2])
# Out:
# (1.0, 2.0)

# %%
fig = plt.figure()
plt.plot([1, 2, 3], [4, 5, 6])

plt.xlabel("time ($s$)", fontsize=14)
# plt.ylabel(r"test + $\rho x = c_m X$", fontsize=14)
plt.ylabel("Frequency (Hz)", fontsize=14)

plt.show()
